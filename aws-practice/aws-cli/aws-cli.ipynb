# %% [markdown]
# # AWS CLI

# %% [raw]
#     The AWS Command Line Interface (CLI) is a unified tool to manage your AWS services.
#
#         •AWS CLI built on top of Python SDK
#         •AWS CLI commands (not all) contain a --dry-run option to simulate API calls
#         •AWS EC2 instance metadata information get it from URL http://169.254.169.254/latest/meta-data

# %%
from IPython.display import Image
i = Image(filename='../images/aws-cli-instance-metadata.png')#Getting metadata information of ec2 instance
i

# %%
from IPython.display import Image
i = Image(filename='../images/CLI-dryrun.png')#Response of dry run enabled API
i
