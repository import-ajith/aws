# %% [markdown]
# # Install Apache on EC2

# %% [raw]
#     Need a root access to install apache on ec2
#     Following are the comments used for installing apache on ec2
#
#          • sudo su
#
#          • yum update -y
#
#          • yum install -y httpd.x86_64
#
#          • systemctl start httpd.service
#
#          • systemctl enable httpd.service

# %% [markdown]
#     Add Inbound security rules to port 80

# %%
from IPython.display import Image
i = Image(filename='../images/apache-input-bound.png')
i

# %%
from IPython.display import Image
i = Image(filename='../images/apache-page.png') #Apache Home Page after succesful installation
i
