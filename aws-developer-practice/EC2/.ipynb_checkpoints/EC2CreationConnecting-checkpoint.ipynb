# %% [markdown]
#     EC2 Creation and Connecting EC2 from Windows 10 cmd

# %%
from IPython.display import Image
i = Image(filename='../images/aws-ec2.png')
i

# %% [markdown]
#     EC2 Connect
#         ssh -i keypath ec2-user@public_ip_address

# %%
from IPython.display import Image
i = Image(filename='../images/ec2-connect.png')
i
